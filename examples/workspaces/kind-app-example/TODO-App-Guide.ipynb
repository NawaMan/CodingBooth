# %% [markdown]
# # TODO App with KIND - Interactive Guide
#
# This notebook walks you through deploying and running the TODO application on a KIND (Kubernetes IN Docker) cluster.
#
# ## Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │  KIND Cluster (todo-app namespace)                              │
# │                                                                 │
# │   ┌──────────────┐      ┌──────────────┐      ┌──────────────┐  │
# │   │    React     │      │   Go API     │      │   Export     │  │
# │   │   (nginx)    │─────▶│   Service    │─────▶│   Service    │  │
# │   │   web:80     │ /api │   api:8080   │ HTTP │ export:8081  │  │
# │   └──────────────┘  /ws └──────────────┘      └──────────────┘  │
# │                              │                                  │
# │                              ▼                                  │
# │                        ┌──────────────┐                         │
# │                        │  PostgreSQL  │                         │
# │                        │ postgres:5432│                         │
# │                        └──────────────┘                         │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# ## Ports
#
# | Port | Service | Description |
# |------|---------|-------------|
# | 3000 | Web UI | React frontend |
# | 8080 | API | Go REST API + WebSocket |
# | 8081 | Export | Go export service (CSV/JSON) |

# %% [markdown]
# ---
# ## 1. Check Current Status
#
# First, let's see the current state of the cluster and app.

# %%
./status.sh
# Out:
# === KIND Cluster Status ===
# ✖ Cluster 'kind' is not running
#   Run: ./start-cluster.sh

# %% [markdown]
# ---
# ## 2. Start the KIND Cluster
#
# Create a KIND cluster configured for the DinD (Docker-in-Docker) environment.
#
# This configures:
# - API server accessible from the workspace container
# - NodePort mappings for external access

# %%
./start-cluster.sh
# Out:
# Creating KinD cluster: kind
# DinD sidecar: kind-app-example-10000-dind
# Creating cluster "kind" ...
#  ✓ Ensuring node image (kindest/node:v1.32.2) 🖼7l
#  ✓ Preparing nodes 📦 7l
#  ✓ Writing configuration 📜7l
#  ✓ Starting control-plane 🕹️7l
#  ✓ Installing CNI 🔌7l
#  ✓ Installing StorageClass 💾7l
#  ✓ Waiting ≤ 1m0s for control-plane = Ready ⏳7l
#  • Ready after 20s 💚
# Set kubectl context to "kind-kind"
# You can now use your cluster with:
#
# kubectl cluster-info --context kind-kind
#
# Have a question, bug, or feature request? Let us know! https://kind.sigs.k8s.io/#community 🙂
#
# Cluster 'kind' is ready!
# NodePorts 30080-30084, 80, 443 are accessible via: localhost
#
# Kubernetes control plane is running at https://0.0.0.0:6443
# CoreDNS is running at https://0.0.0.0:6443/api/v1/namespaces/kube-system/services/kube-dns:dns/proxy
#
# To further debug and diagnose cluster problems, use 'kubectl cluster-info dump'.

# %% [markdown]
# ### Verify the cluster is running

# %%
./check-cluster.sh --expect=up
# Out:
# ✔ SUCCESS: Cluster 'kind' is UP
# NAME                 STATUS   ROLES           AGE   VERSION
# kind-control-plane   Ready    control-plane   26s   v1.32.2

# %% [markdown]
# ---
# ## 3. Build Docker Images
#
# Build all the Docker images for the TODO app:
# - `todo-web` - React frontend served by nginx
# - `todo-api` - Go REST API with WebSocket support
# - `todo-export` - Go export service

# %%
./build.sh
# Out:
# === Building TODO App Docker Images ===
#
# >>> Building API service...
# DEPRECATED: The legacy builder is deprecated and will be removed in a future release.
#             Install the buildx component to build images with BuildKit:
#             https://docs.docker.com/go/buildx/
#
# Sending build context to Docker daemon  31.23kB
# Step 1/11 : FROM golang:1.21-alpine AS builder
# 1.21-alpine: Pulling from library/golang
# 4f4fb700ef54: Pulling fs layer
# 41db7493d1c6: Pulling fs layer
# c6a83fedfae6: Pulling fs layer
# 54bf7053e2d9: Pulling fs layer
# 4579008f8500: Pulling fs layer
# b3f3effce7f5: Download complete
# 4f4fb700ef54: Download complete
# 41db7493d1c6: Download complete
# 4579008f8500: Download complete
# b0059cac77ec: Download complete
# c6a83fedfae6: Download complete
# c6a83fedfae6: Pull complete
# 41db7493d1c6: Pull complete
# 54bf7053e2d9: Download complete
# 4579008f8500: Pull complete
# 54bf7053e2d9: Pull complete
# 4f4fb700ef54: Pull complete
# Digest: sha256:2414035b086e3c42b99654c8b26e6f5b1b1598080d65fd03c7f499552ff4dc94
# Status: Downloaded newer image for golang:1.21-alpine
#  ---> 2414035b086e
# Step 2/11 : WORKDIR /app
#  ---> Running in 9c4dfabfdacc
#  ---> Removed intermediate container 9c4dfabfdacc
#  ---> 127a142dae85
# Step 3/11 : COPY go.mod go.sum* ./
#  ---> f99f84cfa208
# Step 4/11 : RUN go mod download
#  ---> Running in 893a0d6f1fed
#  ---> Removed intermediate container 893a0d6f1fed
#  ---> 7d08b73d6cca
# Step 5/11 : COPY . .
#  ---> 982b3d50246e
# Step 6/11 : RUN CGO_ENABLED=0 GOOS=linux go build -o api .
#  ---> Running in a2b9bdbc1a1a
#  ---> Removed intermediate container a2b9bdbc1a1a
#  ---> c9bc8178428e
# Step 7/11 : FROM alpine:3.19
# 3.19: Pulling from library/alpine
# 17a39c0ba978: Pulling fs layer
# fd18d7b2aa35: Download complete
# ef1614f30685: Download complete
# 17a39c0ba978: Download complete
# 17a39c0ba978: Pull complete
# Digest: sha256:6baf43584bcb78f2e5847d1de515f23499913ac9f12bdf834811a3145eb11ca1
# Status: Downloaded newer image for alpine:3.19
#  ---> 6baf43584bcb
# Step 8/11 : WORKDIR /app
#  ---> Running in 4fa7389b2cf5
#  ---> Removed intermediate container 4fa7389b2cf5
#  ---> cae828f48b8d
# Step 9/11 : COPY --from=builder /app/api .
#  ---> da06d29e5956
# Step 10/11 : EXPOSE 8080
#  ---> Running in 4181a9837359
#  ---> Removed intermediate container 4181a9837359
#  ---> e2b58f8aba98
# Step 11/11 : CMD ["./api"]
#  ---> Running in 1bf9383f02d7
#  ---> Removed intermediate container 1bf9383f02d7
#  ---> 9e87669b0ada
# Successfully built 9e87669b0ada
# Successfully tagged todo-api:latest
#
# >>> Building Export service...
# DEPRECATED: The legacy builder is deprecated and will be removed in a future release.
#             Install the buildx component to build images with BuildKit:
#             https://docs.docker.com/go/buildx/
#
# Sending build context to Docker daemon  12.29kB
# Step 1/11 : FROM golang:1.21-alpine AS builder
#  ---> 2414035b086e
# Step 2/11 : WORKDIR /app
#  ---> Using cache
#  ---> 127a142dae85
# Step 3/11 : COPY go.mod go.sum* ./
#  ---> dc42c46fe56d
# Step 4/11 : RUN go mod download
#  ---> Running in 1c4f6a777a72
#  ---> Removed intermediate container 1c4f6a777a72
#  ---> 472858532830
# Step 5/11 : COPY . .
#  ---> 8e1cf1247a5a
# Step 6/11 : RUN CGO_ENABLED=0 GOOS=linux go build -o export-service .
#  ---> Running in e6c9de26e1d4
#  ---> Removed intermediate container e6c9de26e1d4
#  ---> a51a3a3b6201
# Step 7/11 : FROM alpine:3.19
#  ---> 6baf43584bcb
# Step 8/11 : WORKDIR /app
#  ---> Using cache
#  ---> cae828f48b8d
# Step 9/11 : COPY --from=builder /app/export-service .
#  ---> 5f23e881e35c
# Step 10/11 : EXPOSE 8081
#  ---> Running in e73b697bc187
#  ---> Removed intermediate container e73b697bc187
#  ---> a56d0709f6f5
# Step 11/11 : CMD ["./export-service"]
#  ---> Running in bc6556f86a14
#  ---> Removed intermediate container bc6556f86a14
#  ---> 97b2282fcb60
# Successfully built 97b2282fcb60
# Successfully tagged todo-export:latest
#
# >>> Building Web frontend...
# DEPRECATED: The legacy builder is deprecated and will be removed in a future release.
#             Install the buildx component to build images with BuildKit:
#             https://docs.docker.com/go/buildx/
#
# Sending build context to Docker daemon  86.02kB
# Step 1/10 : FROM oven/bun:1-alpine AS builder
# 1-alpine: Pulling from oven/bun
# 8ec63980c814: Pulling fs layer
# d41034969b92: Pulling fs layer
# a8ce83f3aa1b: Pulling fs layer
# 07c23603f983: Pulling fs layer
# d49a2dee86fb: Pulling fs layer
# 67aa5eb741d3: Pulling fs layer
# ed61753ff37f: Download complete
# 8ec63980c814: Download complete
# d41034969b92: Download complete
# a8ce83f3aa1b: Download complete
# d49a2dee86fb: Download complete
# 67aa5eb741d3: Download complete
# d49a2dee86fb: Pull complete
# 07c23603f983: Download complete
# 07c23603f983: Pull complete
# d41034969b92: Pull complete
# a8ce83f3aa1b: Pull complete
# 67aa5eb741d3: Pull complete
# 8ec63980c814: Pull complete
# Digest: sha256:b0885548002187f088af5c7e04008f852c0a30cbe4192b5d75c3266a7f0b01f5
# Status: Downloaded newer image for oven/bun:1-alpine
#  ---> b08855480021
# Step 2/10 : WORKDIR /app
#  ---> Running in 0520ea411097
#  ---> Removed intermediate container 0520ea411097
#  ---> 9994a2d03808
# Step 3/10 : COPY package.json bun.lockb* ./
#  ---> 9a2bf5ca7eb5
# Step 4/10 : RUN bun install
#  ---> Running in 9ed6a4e3c4ee
# bun install v1.3.8 (b64edcb4)
# Resolving dependencies
# Resolved, downloaded and extracted [632]
# Saved lockfile
#
# + @playwright/test@1.58.1
# + @types/react@18.3.27 (v19.2.10 available)
# + @types/react-dom@18.3.7 (v19.2.3 available)
# + @vitejs/plugin-react@4.7.0 (v5.1.3 available)
# + autoprefixer@10.4.24
# + postcss@8.5.6
# + tailwindcss@3.4.19 (v4.1.18 available)
# + typescript@5.9.3
# + vite@5.4.21 (v7.3.1 available)
# + react@18.3.1 (v19.2.4 available)
# + react-dom@18.3.1 (v19.2.4 available)
#
# 136 packages installed [1.88s]
#  ---> Removed intermediate container 9ed6a4e3c4ee
#  ---> 37bead1a17fb
# Step 5/10 : COPY . .
#  ---> 02461764b770
# Step 6/10 : RUN bun run build
#  ---> Running in 2633186669d8
# $ tsc && vite build
# vite v5.4.21 building for production...
# transforming...
# ✓ 37 modules transformed.
# rendering chunks...
# computing gzip size...
# dist/index.html                   0.46 kB │ gzip:  0.30 kB
# dist/assets/index-BVYZeIzG.css    9.78 kB │ gzip:  2.56 kB
# dist/assets/index-7N9slrbU.js   150.06 kB │ gzip: 48.08 kB
# ✓ built in 990ms
#  ---> Removed intermediate container 2633186669d8
#  ---> 1c9e75ca6e28
# Step 7/10 : FROM nginx:alpine
# alpine: Pulling from library/nginx
# 55cbbd6285fe: Pulling fs layer
# 9739627526d7: Pulling fs layer
# 211bae00ea56: Pulling fs layer
# 9331cd6029cb: Pulling fs layer
# 6c2f4c63521d: Pulling fs layer
# 589002ba0eae: Pulling fs layer
# 76fc765fd3b0: Pulling fs layer
# cd835559902a: Pulling fs layer
# b53c120a8ef7: Download complete
# 529bf64289c0: Download complete
# 9739627526d7: Download complete
# 211bae00ea56: Download complete
# 6c2f4c63521d: Download complete
# cd835559902a: Download complete
# 9331cd6029cb: Download complete
# 76fc765fd3b0: Download complete
# 589002ba0eae: Download complete
# 589002ba0eae: Pull complete
# 211bae00ea56: Pull complete
# 9331cd6029cb: Pull complete
# 55cbbd6285fe: Download complete
# 9739627526d7: Pull complete
# 6c2f4c63521d: Pull complete
# cd835559902a: Pull complete
# 76fc765fd3b0: Pull complete
# 55cbbd6285fe: Pull complete
# Digest: sha256:4870c12cd2ca986de501a804b4f506ad3875a0b1874940ba0a2c7f763f1855b2
# Status: Downloaded newer image for nginx:alpine
#  ---> 4870c12cd2ca
# Step 8/10 : COPY --from=builder /app/dist /usr/share/nginx/html
#  ---> c1fe149e3915
# Step 9/10 : EXPOSE 80
#  ---> Running in 7d7a7a7e68fc
#  ---> Removed intermediate container 7d7a7a7e68fc
#  ---> e4b5126695d6
# Step 10/10 : CMD ["nginx", "-g", "daemon off;"]
#  ---> Running in c250e1ef24b4
#  ---> Removed intermediate container c250e1ef24b4
#  ---> 4d9657770a24
# Successfully built 4d9657770a24
# Successfully tagged todo-web:latest
#
# === All images built successfully ===
#
# Images:
# todo-web       latest        4d9657770a24   1 second ago     92.5MB
# todo-export    latest        97b2282fcb60   24 seconds ago   24.5MB
# todo-api       latest        9e87669b0ada   45 seconds ago   26.9MB

# %% [markdown]
# ### Verify images are built

# %%
docker images | grep -E "todo-|REPOSITORY"
# Out:
# REPOSITORY     TAG           IMAGE ID       CREATED              SIZE
# todo-web       latest        4d9657770a24   26 seconds ago       92.5MB
# todo-export    latest        97b2282fcb60   49 seconds ago       24.5MB
# todo-api       latest        9e87669b0ada   About a minute ago   26.9MB

# %% [markdown]
# ---
# ## 4. Deploy the App to KIND
#
# Deploy all Kubernetes manifests:
# - PostgreSQL (database with persistent volume)
# - API service
# - Export service
# - Web frontend

# %%
./deploy-app.sh
# Out:
# === Deploying TODO App to KIND ===
#
# >>> Loading images into KIND cluster...
# Image: "todo-api:latest" with ID "sha256:9e87669b0adabb1f06b0019400b65eab6b33e9b126685578f546c7c22328af28" not yet present on node "kind-control-plane", loading...
# Image: "todo-export:latest" with ID "sha256:97b2282fcb60bd3b4a2d45a07797cdea9a3972a1aaae5068590d7152a196f0d6" not yet present on node "kind-control-plane", loading...
# Image: "todo-web:latest" with ID "sha256:4d9657770a24a244c7bafe7991d77039b84fba0709b17a4d23f1bfb46c58f5b1" not yet present on node "kind-control-plane", loading...
#
# >>> Creating namespace 'todo-app'...
# namespace/todo-app created
#
# >>> Applying Kubernetes manifests...
# persistentvolumeclaim/postgres-pvc created
# configmap/postgres-config created
# configmap/postgres-init created
# deployment.apps/postgres created
# service/postgres created
#
# >>> Waiting for PostgreSQL to be ready...
# deployment.apps/postgres condition met
# deployment.apps/export-service created
# service/export-service created
# configmap/api-config created
# deployment.apps/api created
# service/api created
# configmap/web-config created
# deployment.apps/web created
# service/web created
#
# >>> Waiting for all deployments to be ready...
# deployment.apps/export-service condition met
# deployment.apps/api condition met
# deployment.apps/web condition met
#
# === Deployment complete ===
#
# Services:
# NAME             TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)    AGE
# api              ClusterIP   10.96.101.236   <none>        8080/TCP   10s
# export-service   ClusterIP   10.96.244.36    <none>        8081/TCP   11s
# postgres         ClusterIP   10.96.216.113   <none>        5432/TCP   43s
# web              ClusterIP   10.96.75.109    <none>        80/TCP     9s
#
# Pods:
# NAME                              READY   STATUS    RESTARTS   AGE
# api-5c69c49fbc-z7wb9              1/1     Running   0          10s
# export-service-5f95c9fb8d-7fljw   1/1     Running   0          11s
# postgres-7d6576884-mjf9z          1/1     Running   0          43s
# web-c47849589-vf88v               1/1     Running   0          10s
#
# >>> To access the application, run:
#     kubectl port-forward svc/web 3000:80 -n todo-app
#
# >>> Then open http://localhost:3000 in your browser

# %%
kubectl port-forward svc/web 3000:80 -n todo-app &
# Out:
# [1] 3997
# : 1

# %%
curl localhost:3000
# Out:
# Handling connection for 3000
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <link rel="icon" type="image/svg+xml" href="/vite.svg" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>TODO App</title>
#     <script type="module" crossorigin src="/assets/index-7N9slrbU.js"></script>
#     <link rel="stylesheet" crossorigin href="/assets/index-BVYZeIzG.css">
#   </head>
#   <body>
#     <div id="root"></div>
#   </body>
# </html>

# %% [markdown]
# ### Check pod status
#
# Wait for all pods to be `Running`. This may take a minute.

# %%
kubectl get pods -n todo-app -w &
# Out:
# [2] 4037

# %% [markdown]
# ### Check services

# %%
kubectl get svc -n todo-app
# Out:
# NAME                              READY   STATUS    RESTARTS   AGE
# api-5c69c49fbc-z7wb9              1/1     Running   0          2m46s
# export-service-5f95c9fb8d-7fljw   1/1     Running   0          2m47s
# postgres-7d6576884-mjf9z          1/1     Running   0          3m19s
# web-c47849589-vf88v               1/1     Running   0          2m46s
# NAME             TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)    AGE
# api              ClusterIP   10.96.101.236   <none>        8080/TCP   2m49s
# export-service   ClusterIP   10.96.244.36    <none>        8081/TCP   2m50s
# postgres         ClusterIP   10.96.216.113   <none>        5432/TCP   3m22s
# web              ClusterIP   10.96.75.109    <none>        80/TCP     2m48s

# %% [markdown]
# ---
# ## 5. Access the App
#
# Start port-forwarding to access the app from your host browser.
#
# **Important:** Uses `--address 0.0.0.0` so the app is accessible through the DinD sidecar's port mapping to your host.

# %%
./access-app.sh
# Out:
# Handling connection for 8081
# Handling connection for 8081
# Starting port-forward for TODO app...
#   Web UI:  http://localhost:3000
#   API:     http://localhost:8080
#   Export:  http://localhost:8081
#
# Forwarding from 0.0.0.0:8080 -> 8080
# Forwarding from 0.0.0.0:8081 -> 8081
# Forwarding from 0.0.0.0:3000 -> 80
#
# Port-forwards started in background.
# Run './access-app-stop.sh' to stop them.

# %% [markdown]
# ### Now open in your browser:
#
# - **Web UI:** [http://localhost:3000](http://localhost:3000)
# - **API:** [http://localhost:8080/api/tasks](http://localhost:8080/api/tasks)
# - **Export (JSON):** [http://localhost:8081/export?format=json](http://localhost:8081/export?format=json)
# - **Export (CSV):** [http://localhost:8081/export?format=csv](http://localhost:8081/export?format=csv)

# %% [markdown]
# ### Test the API directly

# %%
curl -s http://localhost:8080/api/tasks | jq .
# Out:
# Handling connection for 8080
# [
#   {
#     "id": 1,
#     "title": "Buy groceries",
#     "description": "Milk, eggs, bread, and cheese",
#     "completed": false,
#     "created_at": "2026-02-03T00:56:12.918803Z",
#     "updated_at": "2026-02-03T00:56:12.918803Z"
#   },
#   {
#     "id": 2,
#     "title": "Review pull request",
#     "description": "Check the new feature branch for issues",
#     "completed": false,
#     "created_at": "2026-02-03T00:56:12.918803Z",
#     "updated_at": "2026-02-03T00:56:12.918803Z"
#   },
#   {
#     "id": 3,
#     "title": "Schedule dentist appointment",
#     "description": "Call Dr. Smith office",
#     "completed": false,
#     "created_at": "2026-02-03T00:56:12.918803Z",
#     "updated_at": "2026-02-03T00:56:12.918803Z"
#   },
#   {
#     "id": 4,
#     "title": "Finish reading book",
#     "description": "Complete chapters 10-12 of Clean Code",
#     "completed": true,
#     "created_at": "2026-02-03T00:56:12.918803Z",
#     "updated_at": "2026-02-03T00:56:12.918803Z"
#   },
#   {
#     "id": 5,
#     "title": "Update resume",
#     "description": "Add recent project experience",
#     "completed": false,
#     "created_at": "2026-02-03T00:56:12.918803Z",
#     "updated_at": "2026-02-03T00:56:12.918803Z"
#   }
# ]

# %% [markdown]
# ### Create a new task

# %%
curl -s -X POST http://localhost:8080/api/tasks \
  -H "Content-Type: application/json" \
  -d '{"title": "Learn Kubernetes", "description": "Deploy apps to KIND"}' | jq .
# Out:
# Handling connection for 8080
# {
#   "id": 6,
#   "title": "Learn Kubernetes",
#   "description": "Deploy apps to KIND",
#   "completed": false,
#   "created_at": "2026-02-03T00:59:24.078469Z",
#   "updated_at": "2026-02-03T00:59:24.078469Z"
# }

# %% [markdown]
# ### Export tasks as JSON

# %%
curl -s http://localhost:8081/export?format=json | jq .
# Out:
# Handling connection for 8081

# %% [markdown]
# ### Export tasks as CSV

# %%
curl -s http://localhost:8081/export?format=csv
# Out:
# Handling connection for 8081

# %% [markdown]
# ---
# ## 6. View Logs
#
# Check logs from the different services.

# %%
kubectl logs -n todo-app -l app=api --tail=20

# %%
kubectl logs -n todo-app -l app=web --tail=20

# %%
kubectl logs -n todo-app -l app=export --tail=20

# %% [markdown]
# ---
# ## 7. Stop Port-Forwards
#
# Stop the port-forwarding processes when done testing.

# %%
./access-app-stop.sh

# %% [markdown]
# ---
# ## 8. Cleanup
#
# ### Remove the app (keep the cluster)

# %%
./remove-app.sh

# %% [markdown]
# ### Delete the KIND cluster entirely

# %%
./stop-cluster.sh

# %% [markdown]
# ### Verify cluster is stopped

# %%
./check-cluster.sh --expect=down

# %% [markdown]
# ---
# ## Quick Reference
#
# | Script | Description |
# |--------|-------------|
# | `./status.sh` | Show cluster, pods, services, port-forwards |
# | `./start-cluster.sh` | Create KIND cluster |
# | `./stop-cluster.sh` | Delete KIND cluster |
# | `./check-cluster.sh` | Check if cluster is running |
# | `./build.sh` | Build Docker images |
# | `./deploy-app.sh` | Deploy TODO app to cluster |
# | `./remove-app.sh` | Remove TODO app from cluster |
# | `./access-app.sh` | Start port-forwards |
# | `./access-app-stop.sh` | Stop port-forwards |
