# %% [markdown]
# # R Example Notebook
#
# A quick demo of R inside CodingBooth.

# %%
# Generate sample data
set.seed(42)
x <- 1:20
y <- 2 * x + rnorm(20, sd = 3)

# Fit a linear model
model <- lm(y ~ x)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.7756 -1.5761 -0.3986  2.7556  6.6381
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.0531     1.7574   1.737   0.0994 .
# x             1.7641     0.1467  12.025 4.88e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.783 on 18 degrees of freedom
# Multiple R-squared:  0.8893,	Adjusted R-squared:  0.8831
# F-statistic: 144.6 on 1 and 18 DF,  p-value: 4.882e-10

# %%
# Plot the data with the regression line
plot(x, y, pch = 19, col = "steelblue",
     main = "Linear Regression",
     xlab = "x", ylab = "y")
abline(model, col = "red", lwd = 2)
# Out:
# Plot with title “Linear Regression”
